# %% [markdown]
# <a href="https://colab.research.google.com/github/raimukul/python/blob/master/python_L06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Slice Operator
# ----------------------
# -> slice = piece or substring
#
# -> a='durga'
# ![image.png](data:image/png;base64,...)!
#
# there are two types of index is possible
#
# 1. +ive
#
# 2. -ive
# ![image.png](data:image/png;base64,...)

# %%
s='durga'

# %%
# +ive indexing always starts with 0-->compulsory
s[0]
# Out:
# 'd'

# %%
s[1]
# Out:
# 'u'

# %%
s[2]
# Out:
# 'r'

# %%
s[3]
# Out:
# 'g'

# %%
s[4]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 'a'

# %%
s[-2]
# Out:
# 'g'

# %%
s[-3]
# and so on we can get slice of s
# Out:
# 'r'

# %%
s[10]   #string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-34c622ab6870> in <module>()
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s[-4]
# Out:
# 'u'

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-e045f2696f3a> in <module>()
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
#s[begin:end] -->returns substring from begin index to (end-1) index
# it is syntex for slice operator.
s[1:4]
# Out:
# 'urg'

# %%
s[2:4]
# Out:
# 'rg'

# %%
s[0:4]
# Out:
# 'durg'

# %%
s[1:]        # when we not specify end default end value 
             # is end of string
# Out:
# 'urga'

# %%
s[:4]       # when we not specify start default start value
            # is start of string
# Out:
# 'durg'

# %%
s[:]         # when we not specify start as well as end then 
             # default taken start and end value of index.
# Out:
# 'durga'

# %%
s[-1:-4]      #starting value is greater than end value
# Out:
# ''

# %%
s[-4:-1]
# Out:
# 'urg'

# %%
s[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-2a138df92e52> in <module>()
# ----> 1 s[100]
#
# IndexError: string index out of range

# %%
s[1:100]   #if we use endpoint 
      #is greater than end then it take last digit or string.
# Out:
# 'urga'

# %%
 #for jumps in string
 # s[begin:end:step]   step means jump means moving by leaving some(step_value) character
 #-----------------------
 s='durgasoftwaresolutions'
 s[1:10]
# Out:
# 'urgasoftw'

# %%
s[1:10:2]
# Out:
# 'ugsfw'

# %% [markdown]
#  Repeatation operator
#
#  ----------------------
#
#  For print anything without using loop.

# %%
s='durga'

# %%
s*10
# Out:
# 'durgadurgadurgadurgadurgadurgadurgadurgadurgadurga'

# %%
len(s)        #len used for get lenght of string.
# Out:
# 5

# %% [markdown]
# Note
#
# ---------
# int
#
# float
#
# complex
#
# bool
#
# str
#
# --> These are fundamental data type.
#
# --> char data type is not available and it can be used as string(str)
#
# --> long data is available in python2 but not python3. it is available as int in python3.

# %%
c='a'

# %%
type(c)
# Out:
# str

# %% [markdown]
#  Type Casting or type  coersion
#
# <--------------------->
#
# convertion of one type to other type
#
# 1. int()
#
# 2. float()
#
# 3. complex()
#
# 4. bool()
#
# 5. str()
#
#
# #long data type is not available in pythn 3 it is simply used a int.

# %%
# float to  int
int(123.456)
# Out:
# 123

# %%
int(5768.999)
# Out:
# 5768

# %%
# complex to int
int(10+20j)     #we can't convert complex to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-1d92c7307b83> in <module>()
# ----> 1 int(10+20j)
#
# TypeError: can't convert complex to int

# %%
#bool to int
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
# int to int
int(10)
# Out:
# 10

# %%
#str to int 
int('10')
# Out:
# 10

# %%
int(10.5)
# Out:
# 10

# %%
int('10.5') #for string base 10 is compulsory
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-6cc59efdcec3> in <module>()
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
int('11111111111')
# Out:
# 11111111111

# %%
# always should be base 10 means decimal to convert into int
int('0b111111')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-857746455cdf> in <module>()
# ----> 1 int('0b111111')
#
# ValueError: invalid literal for int() with base 10: '0b111111'

# %% [markdown]
# float()
# ----------------

# %%
float(10)
# Out:
# 10.0

# %%
float(10+20j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-48f191a7b6f1> in <module>()
# ----> 1 float(10+20j)
#
# TypeError: can't convert complex to float

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float(10.5)
# Out:
# 10.5

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-84bd4c634f13> in <module>()
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float('0b11111')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-8df08505013f> in <module>()
# ----> 1 float('0b11111')
#
# ValueError: could not convert string to float: '0b11111'

# %%
print(True/True)
# Out:
# 1.0

# %%
print(True/False)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-24f33ef27ce1> in <module>()
# ----> 1 print(True/False)
#
# ZeroDivisionError: division by zero

# %%
dec("10")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-585ee266ebb7> in <module>()
# ----> 1 dec("10")
#
# NameError: name 'dec' is not defined

# %% [markdown]
# dec is not any data type in python. (decimal-dec)

# %%
#float----------------------------
float(10)
# Out:
# 10.0

# %%
float(10+20j) #we can't convert complex to float.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-48f191a7b6f1> in <module>()
# ----> 1 float(10+20j)
#
# TypeError: can't convert complex to float

# %%
float(True)  #true means 1 means decimal
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')   #string to float
# Out:
# 10.0

# %%
float('10.4') #float to float
# Out:
# 10.4

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-84bd4c634f13> in <module>()
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float('10.5')
# Out:
# 10.5

# %%
float('0b1111')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-8a00d88b4550> in <module>()
# ----> 1 float('0b1111')
#
# ValueError: could not convert string to float: '0b1111'

# %%
float(0b000011)
# Out:
# 3.0
